# %% [markdown]
# ## window 작업 환경 만들기
# - git 설치
#   [▶](https://git-scm.com/download/win)
# - nodejs 설치 (npm 자동설치)
#   [▶](https://nodejs.org/en)
# - browser-sync 설치
#   ```
#   npm install -g browser-sync
#
#   ```
#
# - cmd 를 통해 버젼 확인 가능
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## github branch 생성 후, 이동
# - gh-pages에서 작업하기
#   ![image.png](data:image/png;base64,...)
