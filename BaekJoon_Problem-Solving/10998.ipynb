# %% [markdown]
# # 백준풀이
#
# #### No.10998
#
# [문제 링크](https://www.acmicpc.net/problem/10998)

# %% [markdown]
# ### 🐣 내 풀이

# %%
A,B = input().split()
print(int(A)*int(B))

# %% [markdown]
# ### 💡 다른 풀이

# %%
# map 함수를 사용하는 코드
# 1001 풀이 참고
A,B = map(int,input().split())
print(A*B)
