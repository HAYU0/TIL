# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 파이썬 실행하기
#
# - [Git bash 명령어](https://velog.io/@ra2116/Git-bash-%EB%AA%85%EB%A0%B9%EC%96%B4)

# %%
# @title Git bash에서 파이썬 실행하기

python hello.py
